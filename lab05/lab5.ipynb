# %% [markdown]
# # Lab 5

# %%
from qiskit import QuantumCircuit, transpile
from pydantic import BaseModel, ValidationInfo
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram
from qiskit.primitives import Sampler as PSampler
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_ibm_runtime import Batch, Sampler
from numpy import pi
from math import atan, sqrt

# %% [markdown]
# ## Zadanie 1
#  Zaimplementuj algorytm gęstego kodowania w jednym z wybranych symulatorów

# %%
qr = QuantumRegister(4)
qc = QuantumCircuit(qr)

for i in range(4):
    qc.reset(qr[i])

q_state = [0, 1] # encode q2 and q3
for i, q in enumerate(q_state):
    if q == 1: qc.x(qr[i + 2])

# do poprawy na bazie filmiku doktor Rycerz

qc.h(qr[1])
qc.cx(qr[1], qr[0])
qc.cx(qr[2], qr[1])
qc.cz(qr[3], qr[1])
qc.cx(qr[1], qr[0])
qc.h(qr[1])

qc.draw('mpl')

# %%
state = Statevector.from_instruction(qc)
state.draw('latex')
# Out:
# $$ |1010\rangle$$

# %% [markdown]
# ## Zadanie 2
#
# Zaimplementuj algorytm teleportacji kwantowej w jednym z wybranych symulatorów

# %%
qreg_q = QuantumRegister(3, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.reset(qreg_q[1])
circuit.reset(qreg_q[2])
circuit.reset(qreg_q[0])
circuit.h(qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])

circuit.measure(qreg_q[1], creg_c[0])
circuit.measure(qreg_q[0], creg_c[1])

# tutaj wysyłamy gołębia z informacją o stanach - kanał klasyczny

with circuit.if_test((creg_c[0], 0)):
    with circuit.if_test((creg_c[1], 0)):
        circuit.id(qreg_q[2])
    with circuit.if_test((creg_c[1], 1)):
        circuit.cx(qreg_q[1], qreg_q[2])

with circuit.if_test((creg_c[0], 1)):
    with circuit.if_test((creg_c[1], 0)):
        circuit.cz(qreg_q[0], qreg_q[2])
    with circuit.if_test((creg_c[1], 1)):
        circuit.cx(qreg_q[1], qreg_q[2])
        circuit.cz(qreg_q[0], qreg_q[2])

circuit.draw('mpl')

# %%
state = Statevector.from_instruction(circuit)
state.draw('latex')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 state = Statevector.from_instruction(circuit)
#       2 state.draw('latex')
#
# File ~/Studia/8.Semestr/Kwantówka/qiskitenv/lib64/python3.12/site-packages/qiskit/quantum_info/states/statevector.py:763, in Statevector.from_instruction(cls, instruction)
#     761 # Convert circuit to an instruction
#     762 if isinstance(instruction, QuantumCircuit):
# --> 763     instruction = instruction.to_instruction()
#     764 # Initialize an the statevector in the all |0> state
#     765 init = np.zeros(2**instruction.num_qubits, dtype=complex)
#
# File ~/Studia/8.Semestr/Kwantówka/qiskitenv/lib64/python3.12/site-packages/qiskit/circuit/quantumcircuit.py:1596, in QuantumCircuit.to_instruction(self, parameter_map, label)
#    1581 """Create an Instruction out of this circuit.
#    1582
#    1583 Args:
#    (...)
#    1592     (can be decomposed back)
#    1593 """
#    1594 from qiskit.converters.circuit_to_instruction import circuit_to_instruction
# -> 1596 return circuit_to_instruction(self, parameter_map, label=label)
#
# File ~/Studia/8.Semestr/Kwantówka/qiskitenv/lib64/python3.12/site-packages/qiskit/converters/circuit_to_instruction.py:126, in circuit_to_instruction(circuit, parameter_map, equivalence_library, label)
#     124 data = target._data.copy()
#     125 data.replace_bits(qubits=qreg, clbits=creg)
# --> 126 data.map_ops(fix_condition)
#     128 qc = QuantumCircuit(*regs, name=out_instruction.name)
#     129 qc._data = data
#
# File ~/Studia/8.Semestr/Kwantówka/qiskitenv/lib64/python3.12/site-packages/qiskit/converters/circuit_to_instruction.py:113, in circuit_to_instruction.<locals>.fix_condition(op)
#     111 reg, val = condition
#     112 if isinstance(reg, Clbit):
# --> 113     op = op.c_if(clbit_map[reg], val)
#     114 elif reg.size == creg.size:
#     115     op = op.c_if(creg, val)
#
# File ~/Studia/8.Semestr/Kwantówka/qiskitenv/lib64/python3.12/site-packages/qiskit/circuit/controlflow/if_else.py:172, in IfElseOp.c_if(self, classical, val)
#     171 def c_if(self, classical, val):
# --> 172     raise NotImplementedError(
#     173         "IfElseOp cannot be classically controlled through Instruction.c_if. "
#     174         "Please nest it in an IfElseOp instead."
#     175     )
#
# NotImplementedError: IfElseOp cannot be classically controlled through Instruction.c_if. Please nest it in an IfElseOp instead.

# %%
qreg_q = QuantumRegister(3, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.reset(qreg_q[1])
circuit.reset(qreg_q[2])
circuit.reset(qreg_q[0])
circuit.h(qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])

# circuit.measure(qreg_q[1], creg_c[0])
# circuit.measure(qreg_q[0], creg_c[1])

# tutaj wysyłamy gołębia z informacją o stanach - kanał klasyczny

# with circuit.if_test((creg_c[0], 0)):
#     with circuit.if_test((creg_c[1], 0)):
#         circuit.id(qreg_q[2])
#     with circuit.if_test((creg_c[1], 1)):
#         circuit.cx(qreg_q[1], qreg_q[2])

# with circuit.if_test((creg_c[0], 1)):
#     with circuit.if_test((creg_c[1], 0)):
#         circuit.cz(qreg_q[0], qreg_q[2])
#     with circuit.if_test((creg_c[1], 1)):
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cz(qreg_q[0], qreg_q[2])

circuit.draw('mpl')

# %%
state = Statevector.from_instruction(circuit)
state.draw('latex')
# Out:
# $$\frac{1}{2} |000\rangle+\frac{1}{2} |001\rangle+\frac{1}{2} |010\rangle+\frac{1}{2} |011\rangle$$
